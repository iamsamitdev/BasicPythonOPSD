# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in d:\basicpythonopsd\env\lib\site-packages (0.13.0)
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'D:\BasicPythonOPSD\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import xmltodict 
import urllib.request
import re

# %%
Goodread_profile = "https://www.goodreads.com/user/show/73376016-abid"
user_id = ''.join(filter(lambda i: i.isdigit(), Goodread_profile))
user_name = re.findall(r'(?:\d[-.]|[^-.])*(?:[-.]|$)', Goodread_profile.split(user_id, 1)[1])[1]
user_id_name = user_id+'-'+user_name
print(user_id_name)
# Out:
# 73376016-abid

# %%
apiKey = "ZRnySx6awjQuExO9tKEJXw"
version = "2"
shelf = "read"
per_page = "200"

def get_user_data(user_id, apiKey, version, shelf, per_page):
    api_url_base = "https://www.goodreads.com/review/list/"
    final_url = (
        api_url_base
        + user_id
        + ".xml?key="
        + apiKey
        + "&v="
        + version
        + "&shelf="
        + shelf
        + "&per_page="
        + per_page
    )
    contents = urllib.request.urlopen(final_url).read()
    return contents

# %%
contents = get_user_data(user_id_name,apiKey,version, shelf, per_page)
print(contents[0:100])
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<GoodreadsResponse>\n  <Request>\n    <authentication>true</aut'

# %%
contents_json = xmltodict.parse(contents)
print(contents_json["GoodreadsResponse"]["reviews"]["review"][:1])
# Out:
# [{'id': '5140564729', 'book': {'id': {'@type': 'integer', '#text': '6871616'}, 'isbn': '0061783161', 'isbn13': '9780061783166', 'text_reviews_count': {'@type': 'integer', '#text': '1718'}, 'uri': 'kca://book/amzn1.gr.book.v1.xnR2XpnoDmzcdGvvvL4_5g', 'title': 'Eternal Kiss of Darkness (Night Huntress World, #2)', 'title_without_series': 'Eternal Kiss of Darkness', 'image_url': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png', 'small_image_url': 'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png', 'large_image_url': None, 'link': 'https://www.goodreads.com/book/show/6871616-eternal-kiss-of-darkness', 'num_pages': '361', 'format': 'Mass Market Paperback', 'edition_information': None, 'publisher': 'Avon Books', 'publication_day': '27', 'publication_year': '2010', 'publication_month': '7', 'average_rating': '4.21', 'ratings_count': '42753', 'description': "<i>\n  <b>An immortal war has been brewing in the darkness . . . And now one woman has stumbled into the shadows.</b>\n</i><br /><br />Chicago private investigator Kira Graceling should have just kept on walking. But her sense of duty refused to let her ignore the moans of pain coming from inside a warehouse just before dawn. Suddenly she finds herself in a world she's only imagined in her worst nightmares.<br /><br />At the center is Mencheres, a breathtaking Master vampire who thought he'd seen it all. Then Kira appears, this fearless, beautiful . . . <i>human</i> who braved death to rescue him. Though he burns for her, keeping Kira in his world means risking her life. Yet sending her away is unthinkable.<br /><br />But with danger closing in, Mencheres must choose either the woman he craves, or embracing the darkest magic to defeat an enemy bent on his eternal destruction.", 'authors': {'author': {'id': '669810', 'name': 'Jeaniene Frost', 'role': None, 'image_url': {'@nophoto': 'false', '#text': 'https://images.gr-assets.com/authors/1310062695p5/669810.jpg'}, 'small_image_url': {'@nophoto': 'false', '#text': 'https://images.gr-assets.com/authors/1310062695p2/669810.jpg'}, 'link': 'https://www.goodreads.com/author/show/669810.Jeaniene_Frost', 'average_rating': '4.20', 'ratings_count': '976466', 'text_reviews_count': '51612'}}, 'published': '2010', 'work': {'id': '7096800', 'uri': 'kca://work/amzn1.gr.work.v1.1WZn_-gd7tINK3kSQwA7Gg'}}, 'rating': '4', 'votes': '0', 'spoiler_flag': 'false', 'spoilers_state': 'none', 'shelves': {'shelf': {'@name': 'read', '@exclusive': 'true', '@id': '239330059', '@review_shelf_id': ''}}, 'started_at': None, 'read_at': None, 'date_added': 'Fri Dec 02 23:48:14 -0800 2022', 'date_updated': 'Fri Dec 02 23:49:35 -0800 2022', 'read_count': '1', 'body': 'Impressive. I never thought that author can come up with even better story the bones and reaper.', 'comments_count': '0', 'url': 'https://www.goodreads.com/review/show/5140564729', 'link': 'https://www.goodreads.com/review/show/5140564729', 'owned': '0'}]

# %%
df = pd.json_normalize(contents_json["GoodreadsResponse"]["reviews"]["review"])
df = df[df["date_updated"].notnull()]
df.head()
# Out:
#            id rating votes spoiler_flag spoilers_state  \
# 0  5140564729      4     0        false           none
# 1  5118099818      4     0        false           none
# 2  5042887038      4     0        false           none
# 3  5042885001      4     0        false           none
# 4  5042883908      4     0        false           none
#
#                        started_at                         read_at  \
# 0                            None                            None
# 1                            None                            None
# 2  Thu Oct 13 04:10:15 -0700 2022  Sat Oct 29 08:51:40 -0700 2022
# 3                            None                            None
# 4                            None                            None
#
#                        date_added                    date_updated read_count  \
# 0  Fri Dec 02 23:48:14 -0800 2022  Fri Dec 02 23:49:35 -0800 2022          1
# 1  Mon Nov 21 10:28:44 -0800 2022  Mon Nov 21 10:28:50 -0800 2022          1
# 2  Thu Oct 13 04:10:15 -0700 2022  Sat Oct 29 08:51:40 -0700 2022          1
# 3  Thu Oct 13 04:08:06 -0700 2022  Thu Oct 13 04:08:11 -0700 2022          1
# 4  Thu Oct 13 04:06:55 -0700 2022  Thu Oct 13 04:07:12 -0700 2022          1
#
#    ... book.published book.work.id  \
# 0  ...           2010      7096800
# 1  ...           2010      6579128
# 2  ...           2009      5776219
# 3  ...           2008      3612435
# 4  ...           None     58408473
#
#                                        book.work.uri shelves.shelf.@name  \
# 0  kca://work/amzn1.gr.work.v1.1WZn_-gd7tINK3kSQw...                read
# 1  kca://work/amzn1.gr.work.v1.dVD05Xc-uwjpoPEULO...                read
# 2  kca://work/amzn1.gr.work.v1.9nPAgExx2UNOvsv0V0...                read
# 3  kca://work/amzn1.gr.work.v1.Nt-NLlevB28ntSeUUc...                read
# 4  kca://work/amzn1.gr.work.v1.AxrniN9hk9s2lrMKSj...                read
#
#   shelves.shelf.@exclusive shelves.shelf.@id shelves.shelf.@review_shelf_id  \
# 0                     true         239330059
# 1                     true         239330059
# 2                     true         239330059
# 3                     true         239330059
# 4                     true         239330059
#
#   book.isbn.@nil book.isbn13.@nil shelves.shelf
# 0            NaN              NaN           NaN
# 1            NaN              NaN           NaN
# 2            NaN              NaN           NaN
# 3            NaN              NaN           NaN
# 4           true             true           NaN
#
# [5 rows x 59 columns]

# %%
df.dropna(axis=1, how='all', inplace=True)

df
# Out:
#              id rating votes spoiler_flag spoilers_state  \
# 0    5140564729      4     0        false           none
# 1    5118099818      4     0        false           none
# 2    5042887038      4     0        false           none
# 3    5042885001      4     0        false           none
# 4    5042883908      4     0        false           none
# ..          ...    ...   ...          ...            ...
# 195  2402254359      3     0        false           none
# 196  2402253763      3     0        false           none
# 197  2402253464      3     0        false           none
# 198  2402253236      0     0        false           none
# 199  2402253033      3     0        false           none
#
#                          started_at                         read_at  \
# 0                              None                            None
# 1                              None                            None
# 2    Thu Oct 13 04:10:15 -0700 2022  Sat Oct 29 08:51:40 -0700 2022
# 3                              None                            None
# 4                              None                            None
# ..                              ...                             ...
# 195                            None                            None
# 196                            None                            None
# 197  Fri May 25 00:11:14 -0700 2018  Tue Aug 07 07:55:53 -0700 2018
# 198                            None                            None
# 199                            None                            None
#
#                          date_added                    date_updated  \
# 0    Fri Dec 02 23:48:14 -0800 2022  Fri Dec 02 23:49:35 -0800 2022
# 1    Mon Nov 21 10:28:44 -0800 2022  Mon Nov 21 10:28:50 -0800 2022
# 2    Thu Oct 13 04:10:15 -0700 2022  Sat Oct 29 08:51:40 -0700 2022
# 3    Thu Oct 13 04:08:06 -0700 2022  Thu Oct 13 04:08:11 -0700 2022
# 4    Thu Oct 13 04:06:55 -0700 2022  Thu Oct 13 04:07:12 -0700 2022
# ..                              ...                             ...
# 195  Fri May 25 00:13:31 -0700 2018  Tue May 29 08:24:47 -0700 2018
# 196  Fri May 25 00:11:59 -0700 2018  Tue May 29 08:24:49 -0700 2018
# 197  Fri May 25 00:11:13 -0700 2018  Fri Jan 03 09:37:07 -0800 2020
# 198  Fri May 25 00:10:39 -0700 2018  Fri May 25 00:10:40 -0700 2018
# 199  Fri May 25 00:10:10 -0700 2018  Fri Jan 03 09:38:59 -0800 2020
#
#     read_count  ... book.published book.work.id  \
# 0            1  ...           2010      7096800
# 1            1  ...           2010      6579128
# 2            1  ...           2009      5776219
# 3            1  ...           2008      3612435
# 4            1  ...           None     58408473
# ..         ...  ...            ...          ...
# 195          1  ...           2014     41372439
# 196          1  ...           2004      1312015
# 197          1  ...           2001      2755122
# 198          1  ...           2013     25670400
# 199          1  ...           2018     56144100
#
#                                          book.work.uri shelves.shelf.@name  \
# 0    kca://work/amzn1.gr.work.v1.1WZn_-gd7tINK3kSQw...                read
# 1    kca://work/amzn1.gr.work.v1.dVD05Xc-uwjpoPEULO...                read
# 2    kca://work/amzn1.gr.work.v1.9nPAgExx2UNOvsv0V0...                read
# 3    kca://work/amzn1.gr.work.v1.Nt-NLlevB28ntSeUUc...                read
# 4    kca://work/amzn1.gr.work.v1.AxrniN9hk9s2lrMKSj...                read
# ..                                                 ...                 ...
# 195  kca://work/amzn1.gr.work.v1.ukhCQNgKlKtMYf1qxt...                read
# 196  kca://work/amzn1.gr.work.v1.L7TycK7Y2hCvoDs93l...                read
# 197  kca://work/amzn1.gr.work.v1.MrXDSBxlUzua2BxyeB...                read
# 198  kca://work/amzn1.gr.work.v1.wlEBMjrDqVGZhzqFaK...                read
# 199  kca://work/amzn1.gr.work.v1.FBexR-OL20twaWiEnd...                read
#
#     shelves.shelf.@exclusive shelves.shelf.@id shelves.shelf.@review_shelf_id  \
# 0                       true         239330059
# 1                       true         239330059
# 2                       true         239330059
# 3                       true         239330059
# 4                       true         239330059
# ..                       ...               ...                            ...
# 195                     true         239330059
# 196                     true         239330059
# 197                     true         239330059
# 198                     true         239330059
# 199                     true         239330059
#
#     book.isbn.@nil book.isbn13.@nil shelves.shelf
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3              NaN              NaN           NaN
# 4             true             true           NaN
# ..             ...              ...           ...
# 195           true              NaN           NaN
# 196            NaN              NaN           NaN
# 197            NaN              NaN           NaN
# 198            NaN              NaN           NaN
# 199            NaN              NaN           NaN
#
# [200 rows x 58 columns]

# %%
final_df = df[
    [
        "rating",
        "started_at",
        "read_at",
        "date_added",
        "book.title",
        "book.average_rating",
        'book.ratings_count',
        "book.publication_year",
        "book.authors.author.name"
    ]
]
final_df.head()
# Out:
#   rating                      started_at                         read_at  \
# 0      4                            None                            None
# 1      4                            None                            None
# 2      4  Thu Oct 13 04:10:15 -0700 2022  Sat Oct 29 08:51:40 -0700 2022
# 3      4                            None                            None
# 4      4                            None                            None
#
#                        date_added  \
# 0  Fri Dec 02 23:48:14 -0800 2022
# 1  Mon Nov 21 10:28:44 -0800 2022
# 2  Thu Oct 13 04:10:15 -0700 2022
# 3  Thu Oct 13 04:08:06 -0700 2022
# 4  Thu Oct 13 04:06:55 -0700 2022
#
#                                           book.title book.average_rating  \
# 0  Eternal Kiss of Darkness (Night Huntress World...                4.21
# 1   First Drop of Crimson (Night Huntress World, #1)                4.14
# 2   Destined for an Early Grave (Night Huntress, #4)                4.32
# 3                At Grave's End (Night Huntress, #3)                4.29
# 4  THINK STRAIGHT: Change Your Thoughts, Change Y...                3.92
#
#   book.ratings_count book.publication_year book.authors.author.name
# 0              42753                  2010           Jeaniene Frost
# 1              56127                  2010           Jeaniene Frost
# 2              83096                  2009           Jeaniene Frost
# 3              87382                  2008           Jeaniene Frost
# 4              12019                  None            Darius Foroux

# %%
final_df.to_csv("abid_goodreads_clean_data.csv",index=False)
